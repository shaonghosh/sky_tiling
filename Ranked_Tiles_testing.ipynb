# %%
import numpy as np
import rankedTilesGenerator

# %%
skymap_file = '/Users/ghosh4/Downloads/2016_fits/359907/bayestar.fits.gz'

ztf_tileObj = rankedTilesGenerator.RankedTileGenerator(skymap_file)
[ztf_ranked_tile_indices, ztf_ranked_tile_probs] = ztf_tileObj.getRankedTiles()
ztf_tileObj.plotTiles(ztf_ranked_tile_indices, ztf_ranked_tile_probs, 'ZTF_tiles_set1_nowrap_indexed.dat', tileEdges=True)
# Out:
# /opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/mpl_toolkits/basemap/__init__.py:1623: MatplotlibDeprecationWarning: The get_axis_bgcolor function was deprecated in version 2.0. Use get_facecolor instead.
#   fill_color = ax.get_axis_bgcolor()
# /opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/mpl_toolkits/basemap/__init__.py:3260: MatplotlibDeprecationWarning: The ishold function was deprecated in version 2.0.
#   b = ax.ishold()
# /opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/mpl_toolkits/basemap/__init__.py:3269: MatplotlibDeprecationWarning: axes.hold is deprecated.
#     See the API Changes document (http://matplotlib.org/api/api_changes.html)
#     for more details.
#   ax.hold(b)

# %%
atlas_tileObj = rankedTilesGenerator.RankedTileGenerator(skymap_file, preComputed_64='preComputed_ATLAS_pixel_indices_64.dat', 
                                                  preComputed_128='preComputed_ATLAS_pixel_indices_128.dat',
                                                  preComputed_256='preComputed_ATLAS_pixel_indices_256.dat',
                                                  preComputed_512='preComputed_ATLAS_pixel_indices_512.dat',
                                                  preComputed_1024='preComputed_ATLAS_pixel_indices_1024.dat',
                                                  preComputed_2048='preComputed_ATLAS_pixel_indices_2048.dat')

[atlas_ranked_tile_indices, atlas_ranked_tile_probs] = atlas_tileObj.getRankedTiles()
atlas_tileObj.plotTiles(atlas_ranked_tile_indices, atlas_ranked_tile_probs, 'ATLAS_tiles_indexed.dat')
